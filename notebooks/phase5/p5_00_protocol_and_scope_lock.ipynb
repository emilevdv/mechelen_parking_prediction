# %% [markdown]
# # Phase 5 — p5_00 Protocol and Scope Lock

# %% [markdown]
# Doel: scope locken, Phase 4 artefacts valideren, en Phase 5 protocol + model scope formeel vastzetten.

# %%
from pathlib import Path
import sys


def _add_project_root_to_syspath() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "src").exists() and (candidate / "data_processed").exists():
            if str(candidate) not in sys.path:
                sys.path.insert(0, str(candidate))
            return candidate
    raise RuntimeError("Project root with `src/` and `data_processed/` not found in current path hierarchy.")


PROJECT_ROOT = _add_project_root_to_syspath()

from IPython.display import display
from src.phase5.protocol import get_phase5_paths, run_phase5_scope_lock

paths = get_phase5_paths()
result = run_phase5_scope_lock(paths=paths)

print('Protocol:', result['paths']['phase5_protocol_md'])
print('Scope:', result['paths']['phase5_model_scope_csv'])
print('Checks:', result['paths']['phase5_scope_checks_csv'])

print("Scope")
display(result['scope'])

print("Checks")
display(result['checks'])
# Out:
# Protocol: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_protocol.md
# Scope: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_model_scope.csv
# Checks: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_scope_checks.csv
# Scope
#       track       role                   run_id   model_family  \
# 0    policy    primary            P4_ridge_a1_0          ridge
# 1  forecast    primary          F3_rf_90_d12_l2  random_forest
# 2    policy  benchmark      P0_profile_baseline       baseline
# 3  forecast  benchmark  F0_persistence_baseline       baseline
#
#                        feature_set_id           row_filter         claim_scope
# 0            policy_tse_exante_strict                 none   fold_plus_holdout
# 1  forecast_tsel_core_strict_lagvalid  l_valid_all_core==1   fold_plus_holdout
# 2                    baseline_profile                 none  benchmark_contrast
# ...
