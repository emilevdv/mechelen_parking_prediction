# %% [markdown]
# # Phase 5 — p5_03 Iterative Critique and Refine

# %% [markdown]
# Doel: iteratieve zelfkritiek toepassen met harde bijstuurregels en eventuele gerichte reruns uitvoeren.

# %%
from pathlib import Path
import sys


def _add_project_root_to_syspath() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "src").exists() and (candidate / "data_processed").exists():
            if str(candidate) not in sys.path:
                sys.path.insert(0, str(candidate))
            return candidate
    raise RuntimeError("Project root with `src/` and `data_processed/` not found in current path hierarchy.")


PROJECT_ROOT = _add_project_root_to_syspath()

from IPython.display import display
from src.phase5.protocol import get_phase5_paths, run_phase5_iterative_refine

paths = get_phase5_paths()
result = run_phase5_iterative_refine(paths=paths)

print('Iterative log:', result['paths']['phase5_iterative_critique_log_csv'])
print('Claim policy flags:', result['paths']['phase5_claim_policy_flags_json'])

print("Iterative critique log")
display(result['iterative_log'])

print("Policy flags")
print(result['policy_flags'])
# Out:
# 100%|===================| 9977/10000 [04:06<00:00]
# Iterative log: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_iterative_critique_log.csv
# Claim policy flags: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_claim_policy_flags.json
# Iterative critique log
#                                         rule     value  threshold  triggered  \
# 0                    top10_jaccard_threshold  0.501832       0.60       True
# 1                   p4_direction_consistency  0.766667       0.65      False
# 2                 tier_delta_ci_crosses_zero  0.500000       0.00       True
# 3  benchmark_better_than_primary_holdout_mae  1.000000       0.00       True
#
#                                               action  \
# 0                     rerun_shap_with_larger_samples
# 1                            keep_directional_claims
# 2  suppress_hard_tier_claims_for_non_significant_...
# ...
