# %% [markdown]
# # Phase 5 — p5_01 Refit Primary Models and Compute SHAP

# %% [markdown]
# Doel: primaire modellen (P4/F3) refitten op Phase 4 lagen en SHAP op fold + holdout context berekenen.

# %%
from pathlib import Path
import sys


def _add_project_root_to_syspath() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "src").exists() and (candidate / "data_processed").exists():
            if str(candidate) not in sys.path:
                sys.path.insert(0, str(candidate))
            return candidate
    raise RuntimeError("Project root with `src/` and `data_processed/` not found in current path hierarchy.")


PROJECT_ROOT = _add_project_root_to_syspath()

from IPython.display import display
from src.phase5.protocol import get_phase5_paths, run_phase5_shap_core

paths = get_phase5_paths()
result = run_phase5_shap_core(paths=paths)

print('Row-level SHAP:', result['paths']['phase5_shap_rowlevel_samples_parquet'])
print('Global SHAP:', result['paths']['phase5_shap_global_importance_csv'])
print('Tier SHAP:', result['paths']['phase5_shap_tier_importance_csv'])
print('Additivity checks:', result['paths']['phase5_shap_additivity_checks_csv'])

print("Global importance (head)")
display(result['global_importance'].head(40))

print("Additivity checks")
display(result['additivity_checks'])
# Out:
# 100%|===================| 5997/6000 [02:30<00:00]
# Row-level SHAP: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_shap_rowlevel_samples.parquet
# Global SHAP: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_shap_global_importance.csv
# Tier SHAP: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_shap_tier_importance.csv
# Additivity checks: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_shap_additivity_checks.csv
# Global importance (head)
#            run_id   track  context  fold_id                   feature_name  \
# 0   P4_ridge_a1_0  policy  holdout  holdout                t_season__zomer
# 1   P4_ridge_a1_0  policy  holdout  holdout        s_parking_id__p_maarten
# 2   P4_ridge_a1_0  policy  holdout  holdout                     t_hour_cos
# 3   P4_ridge_a1_0  policy  holdout  holdout     s_parking_id__p_hoogstraat
# ...
