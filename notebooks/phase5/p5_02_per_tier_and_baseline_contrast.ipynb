# %% [markdown]
# # Phase 5 — p5_02 Per-Tier Contrast and Baseline Diagnostics

# %% [markdown]
# Doel: per-tier SHAP contrasten + bootstrap/permutation tests maken en benchmarkdiagnostiek exporteren.

# %%
from pathlib import Path
import sys


def _add_project_root_to_syspath() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "src").exists() and (candidate / "data_processed").exists():
            if str(candidate) not in sys.path:
                sys.path.insert(0, str(candidate))
            return candidate
    raise RuntimeError("Project root with `src/` and `data_processed/` not found in current path hierarchy.")


PROJECT_ROOT = _add_project_root_to_syspath()

from IPython.display import display
from src.phase5.protocol import get_phase5_paths, run_phase5_tier_contrast

paths = get_phase5_paths()
result = run_phase5_tier_contrast(paths=paths)

print('Tier delta tests:', result['paths']['phase5_shap_tier_delta_tests_csv'])
print('Fold stability:', result['paths']['phase5_shap_fold_stability_csv'])
print('Baseline diagnostics:', result['paths']['phase5_baseline_diagnostics_csv'])

print("Tier delta tests (head)")
display(result['tier_delta_tests'].head(40))

print("Fold stability (head)")
display(result['fold_stability'].head(40))

print("Baseline diagnostics")
display(result['baseline_diagnostics'])
# Out:
# Tier delta tests: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_shap_tier_delta_tests.csv
# Fold stability: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_shap_fold_stability.csv
# Baseline diagnostics: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_baseline_diagnostics.csv
# Tier delta tests (head)
#              run_id     track  context                   feature_name  \
# 0   F3_rf_90_d12_l2  forecast  holdout         e_event_scale_is_large
# 1   F3_rf_90_d12_l2  forecast  holdout              e_event_scale_max
# 2   F3_rf_90_d12_l2  forecast  holdout    e_football_kickoff_hour_cos
# 3   F3_rf_90_d12_l2  forecast  holdout    e_football_kickoff_hour_sin
# 4   F3_rf_90_d12_l2  forecast  holdout         e_has_football_kickoff
# 5   F3_rf_90_d12_l2  forecast  holdout     e_int_event_x_tier_centrum
# 6   F3_rf_90_d12_l2  forecast  holdout   e_int_holiday_x_tier_centrum
# ...
