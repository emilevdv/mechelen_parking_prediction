# %% [markdown]
# # Phase 5 — p5_04 Thesis Interpretation Memo

# %% [markdown]
# Doel: thesis-ready synthese maken met claimregister en kritische, genuanceerde interpretatiememo.

# %%
from pathlib import Path
import sys


def _add_project_root_to_syspath() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "src").exists() and (candidate / "data_processed").exists():
            if str(candidate) not in sys.path:
                sys.path.insert(0, str(candidate))
            return candidate
    raise RuntimeError("Project root with `src/` and `data_processed/` not found in current path hierarchy.")


PROJECT_ROOT = _add_project_root_to_syspath()

from IPython.display import display
from src.phase5.protocol import get_phase5_paths, run_phase5_memo

paths = get_phase5_paths()
result = run_phase5_memo(paths=paths)

print('Claims:', result['paths']['phase5_interpretation_claims_csv'])
print('Memo:', result['paths']['phase5_interpretation_memo_md'])

print("Claims (head)")
display(result['claims'].head(40))
# Out:
# Claims: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_interpretation_claims.csv
# Memo: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase5/phase5_interpretation_memo.md
# Claims (head)
#    claim_id     track                                         claim_text  \
# 0      C001    policy  t_season__zomer is among the dominant explanat...
# 1      C002    policy  s_parking_id__p_maarten is among the dominant ...
# 2      C003    policy  t_hour_cos is among the dominant explanatory f...
# 3      C004    policy  s_parking_id__p_hoogstraat is among the domina...
# 4      C005    policy  e_int_temp_x_season__zomer is among the domina...
# 5      C006    policy  e_n_concurrent_events_capped is among the domi...
# 6      C007    policy  t_hour_sin is among the dominant explanatory f...
# 7      C008    policy  s_parking_id__p_tinel is among the dominant ex...
# ...
