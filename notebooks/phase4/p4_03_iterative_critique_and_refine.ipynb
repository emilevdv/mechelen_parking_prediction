# %% [markdown]
# # Phase 4 — p4_03 Iterative Critique and Refine

# %% [markdown]
# Doel: zelfkritische evaluatie van iteratie 1, beperkte bijsturing volgens harde regels, shortlist opstellen.

# %%
from pathlib import Path
import sys


def _add_project_root_to_syspath() -> Path:
    cwd = Path.cwd().resolve()
    for candidate in [cwd, *cwd.parents]:
        if (candidate / "src").exists() and (candidate / "data_processed").exists():
            if str(candidate) not in sys.path:
                sys.path.insert(0, str(candidate))
            return candidate
    raise RuntimeError("Project root with `src/` and `data_processed/` not found in current path hierarchy.")


PROJECT_ROOT = _add_project_root_to_syspath()

from IPython.display import display
from src.phase4.protocol import get_phase4_paths, run_iterative_critique_and_refine

paths = get_phase4_paths()
result = run_iterative_critique_and_refine(paths=paths)

print('Shortlist:', result['shortlist_csv'])

print("\nIterative critique log")
display(result['iterative_log'])

print("\nModel selection shortlist")
display(result['shortlist'])
# Out:
# Shortlist: /Users/emilevandevoorde/Documents/mp_mechelen_parking_v2/data_results/phase4/phase4_model_selection_shortlist.csv
#
# Iterative critique log
#                        rule  value  \
# 0  high_variability_trigger     10
# 1     refinement_runs_added      4
# 2              f4_keep_rule      0
#
#                                               detail
# 0  count of fold-safe runs with std(MAE)/mean(MAE...
# 1  limited targeted reruns added only when variab...
# 2           F4 gain=10.850% vs F2; retention=21.421%
# Model selection shortlist
#       track variant                   run_id    cv_mode   model_family  \
# 0  forecast      F0  F0_persistence_baseline  fold_safe       baseline
# 1  forecast      F1       F1_xgb_80_d4_lr006  fold_safe        xgboost
# 2  forecast      F2          F2_rf_90_d12_l2  fold_safe  random_forest
# 3  forecast      F3          F3_rf_90_d12_l2  fold_safe  random_forest
# 4  forecast      F4          F4_rf_90_d12_l2  fold_safe  random_forest
# ...
